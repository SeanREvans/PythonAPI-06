# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key
print(api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# 8836da40ed8c90ca865cb0b966c11cb8

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 303

# %%
cities
# Out:
# ['hermanus',
#  'karaul',
#  'nemuro',
#  'prince rupert',
#  'busselton',
#  'dikson',
#  'kaitangata',
#  'lebu',
#  'khatanga',
#  'uthal',
#  'tasiilaq',
#  'barrow',
#  'tiksi',
#  'bajil',
#  'rikitea',
#  'ariquemes',
#  'taolanaro',
#  'beloha',
#  'portland',
#  'vaitupu',
#  'cape town',
#  'mar del plata',
#  'sao joao da barra',
#  'turayf',
#  'comodoro rivadavia',
#  'yellowknife',
#  'carndonagh',
#  'berbera',
#  'clyde',
#  'port macquarie',
#  'sorvag',
#  'ushuaia',
#  'punta arenas',
#  'hambantota',
#  'kyzyl-suu',
#  'manaus',
#  'kavieng',
#  'sterling',
#  'marzuq',
#  'hirara',
#  'poso',
#  'hilo',
#  'quijingue',
#  'aguimes',
#  'nome',
#  'sao jose da coroa grande',
#  'hvolsvollur',
#  'marawi',
#  'ixtapa',
#  'airai',
#  'uglich',
#  'half moon bay',
#  'iqaluit',
#  'sao filipe',
#  'arlit',
#  'port elizabeth',
#  'albany',
#  'katsuura',
#  'aberdeen',
#  'narsaq',
#  'talnakh',
#  'mataura',
#  'halalo',
#  'huarmey',
#  'constantine',
# ...

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

count = 0
lat_list = []
long_list = []
city_name_list = []
temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []

for city in cities:
    count = count + 1
    print(city)
    try:
        query_url = url + "appid=" + api_key + "&q=" + city
        print(query_url) 
        city_json = requests.get(query_url).json()
        pprint(city_json)
        city_name = city_json["name"]
        city_name_list.append(city_name)
        wind_speed_list.append(city_json["wind"]["speed"])
        lat_list.append(city_json["coord"]["lat"])
        long_list.append(city_json["coord"]["lon"])
        temp_list.append(city_json["main"]["temp_max"])
        cloudiness_list.append(city_json["clouds"]["all"])
        humidity_list.append(city_json["main"]["humidity"])
    except:
        print("weather for city not found " + city) 

    
    
print(len(lat_list))
print(len(long_list))
print(len(city_name_list))
print(len(temp_list))
# Out:
# hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=hermanus
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1554591721,
#  'id': 3366880,
#  'main': {'humidity': 90,
#           'pressure': 1011,
#           'temp': 289.57,
#           'temp_max': 289.82,
#           'temp_min': 289.26},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'message': 0.0036,
#          'sunrise': 1554613170,
#          'sunset': 1554654640,
#          'type': 3},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 121, 'gust': 3.13, 'speed': 2.24}}
# karaul
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=karaul
# {'cod': '404', 'message': 'city not found'}
# weather for city not found karaul
# nemuro
# ...

# %%
weather_dict={"City":city_name_list,"Cloudiness":cloudiness_list,
            "Humidity":humidity_list,"Latitude":lat_list,"Longitude":long_list,"Max_temp":temp_list,
            "Wind_speed":wind_speed_list}
weather_dict
# Out:
# {'City': ['Hermanus',
#   'Nemuro',
#   'Prince Rupert',
#   'Busselton',
#   'Dikson',
#   'Kaitangata',
#   'Lebu',
#   'Khatanga',
#   'Uthal',
#   'Tasiilaq',
#   'Barrow',
#   'Tiksi',
#   'Bajil',
#   'Rikitea',
#   'Ariquemes',
#   'Beloha',
#   'Portland',
#   'Cape Town',
#   'Mar del Plata',
#   'Sao Joao da Barra',
#   'Turayf',
#   'Comodoro Rivadavia',
#   'Yellowknife',
#   'Carndonagh',
#   'Clyde',
#   'Port Macquarie',
#   'Ushuaia',
#   'Punta Arenas',
#   'Hambantota',
#   'Kyzyl-Suu',
#   'Manaus',
#   'Kavieng',
#   'Sterling',
#   'Marzuq',
#   'Hirara',
#   'Poso',
#   'Hilo',
#   'Quijingue',
#   'Aguimes',
#   'Nome',
#   'Sao Jose da Coroa Grande',
#   'Marawi',
#   'Ixtapa',
#   'Airai',
#   'Uglich',
#   'Half Moon Bay',
#   'Iqaluit',
#   'Sao Filipe',
#   'Arlit',
#   'Port Elizabeth',
#   'Albany',
#   'Katsuura',
#   'Aberdeen',
#   'Narsaq',
#   'Talnakh',
#   'Mataura',
#   'Huarmey',
#   'Constantine',
#   'Trebinje',
#   'Cabo San Lucas',
# ...

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#                    City  Cloudiness  Humidity  Latitude  Longitude  Max_temp  \
# 0              Hermanus          48        90    -34.42      19.24   289.820
# 1                Nemuro           0        91     43.32     145.57   275.036
# 2         Prince Rupert          75        43     54.32    -130.32   286.150
# 3             Busselton           8       100    -33.64     115.35   290.286
# 4                Dikson          80       100     73.51      80.55   263.686
# 5            Kaitangata           0        47    -46.28     169.85   286.480
# 6                  Lebu           0        81      8.96      38.73   283.136
# 7              Khatanga          88        94     71.98     102.47   264.586
# 8                 Uthal           0        80     25.81      66.62   291.786
# 9              Tasiilaq          92        50     65.61     -37.64   272.150
# 10               Barrow           0        45    -38.31     -60.23   291.186
# ...

# %%
# Save dataframe to CSV
weather_df.to_csv("Weatherpy.csv")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Build Scatter plot for Latitude v Temperature

# %%
#Build Scatter plot for Latitude v Temperature

    
plt.scatter(weather_df["Latitude"], 
            weather_df["Max_temp"], c="grey",
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")
 
    

plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude") 
plt.title("City Latitude vs. Max Temperature")
plt.grid(True)

# Save the figure
plt.savefig("WeatherPy_Lat_v_Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"], 
            weather_df["Humidity"], c="grey",
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")

plt.title("City Latitude v Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],
            weather_df["Cloudiness"], c="grey",
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="City")

plt.title="City Latitude v Cloudiness"
plt.xlabel= "Latitude"
plt.ylabel= "Cloudiness (%)"
plt.grid=(True)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],
           weather_df["Wind_speed"], c="grey",
           edgecolor="black",linewidth=1, marker="o",
           alpha)

# %%
DONT FORGET TO SET SIZE BACK TO HIGHER ~ 1500
