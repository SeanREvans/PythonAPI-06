# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key
print(api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# 8836da40ed8c90ca865cb0b966c11cb8

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 287

# %%
cities
# Out:
# ['rikitea',
#  'mataura',
#  'yellowknife',
#  'bredasdorp',
#  'avarua',
#  'tabuk',
#  'busselton',
#  'longyearbyen',
#  'hermanus',
#  'port alfred',
#  'qaanaaq',
#  'beloha',
#  'punta arenas',
#  'soe',
#  'kapaa',
#  'havre-saint-pierre',
#  'grafton',
#  'barrow',
#  'kloulklubed',
#  'owando',
#  'tessalit',
#  'provideniya',
#  'road town',
#  'atuona',
#  'wajir',
#  'high level',
#  'attawapiskat',
#  'dunedin',
#  'okha',
#  'albany',
#  'maceio',
#  'pangnirtung',
#  'aguimes',
#  'ushuaia',
#  'ancud',
#  'cidreira',
#  'clarence town',
#  'ucluelet',
#  'saldanha',
#  'kavaratti',
#  'kachug',
#  'abha',
#  'thompson',
#  'jamestown',
#  'ostrovnoy',
#  'shache',
#  'huarmey',
#  'pallasovka',
#  'hobart',
#  'malakisi',
#  'touros',
#  'arraial do cabo',
#  'monroe',
#  'belushya guba',
#  'ilulissat',
#  'taolanaro',
#  'estelle',
#  'chuy',
#  'illoqqortoormiut',
#  'carnarvon',
#  'hamilton',
#  'inhambane',
#  'dondo',
#  'tasiilaq',
#  'katsiveli',
#  'haines junction',
#  'colgong',
#  'karaul',
#  'awjilah',
#  'aqtobe',
#  'egvekinot',
#  'fort nelson',
#  'butaritari',
#  'lavrentiya',
#  'esmeraldas',
#  'tuatapere',
#  'puerto ayora',
#  'katsuura',
#  'kutum',
#  'nuevo progreso',
#  'fortuna',
#  'shahpura',
#  'castro',
#  'port elizabeth',
#  'pierre',
#  'santa cruz de la palma',
#  'vaini',
#  'petropavlovsk-kamchatskiy',
#  'hithadhoo',
#  'rawson',
#  'new norfolk',
#  'biltine',
#  'smithers',
#  'cape town',
#  'barentsburg',
#  'barbar',
#  'santa cruz',
#  'fereydun kenar',
#  'hachinohe',
#  'nikolskoye',
#  'ribeira grande',
#  'channel-port aux basques',
#  'harper',
#  'krasnoselkup',
#  'khatanga',
#  'kailua',
#  'kronach',
#  'bluff',
#  'bandarbeyla',
#  'naifaru',
#  'georgetown',
#  'gazanjyk',
#  'caconda',
#  'toliary',
#  'boaco',
#  'naples',
#  'mar del plata',
#  'san roque',
#  'sept-iles',
#  'dulce grande',
#  'roros',
#  'lebu',
#  'san patricio',
#  'upernavik',
#  'severo-kurilsk',
#  'forbes',
#  'sur',
#  'los lunas',
#  'port hawkesbury',
#  'mahebourg',
#  'high prairie',
#  'nabire',
#  'leningradskiy',
#  'pisco',
#  'kaitangata',
#  'esperance',
#  'pampa',
#  'laguna',
#  'cervo',
#  'kuybysheve',
#  'bethel',
#  'cumaribo',
#  'north bend',
#  'vila velha',
#  'sebring',
#  'auki',
#  'taltal',
#  'saint-philippe',
#  'victoria',
#  'makakilo city',
#  'lubin',
#  'mehamn',
#  'marienburg',
#  'san cristobal',
#  'torbay',
#  'hobyo',
#  'sibolga',
#  'sorland',
#  'avera',
#  'palauig',
#  'west odessa',
#  'geraldton',
#  'dikson',
#  'gat',
#  'tumannyy',
#  'epe',
#  'maricaban',
#  'lagoa',
#  'viedma',
#  'bathsheba',
#  'hayward',
#  'doha',
#  'okhotsk',
#  'novyy urengoy',
#  'kavieng',
#  'dzhusaly',
#  'kruisfontein',
#  'sao filipe',
#  'stargard szczecinski',
#  'saskylakh',
#  'san marcos',
#  'coquimbo',
#  'byron bay',
#  'christchurch',
#  'dolores',
#  'panguna',
#  'sterling',
#  'comarapa',
#  'storforshei',
#  'kismayo',
#  'nantucket',
#  'fairfield',
#  'hasaki',
#  'cap-aux-meules',
#  'rungata',
#  'salinopolis',
#  'pangai',
#  'jujuy',
#  'sibu',
#  'kataysk',
#  'amderma',
#  'labutta',
#  'bajitpur',
#  'usinsk',
#  'la orilla',
#  'jalu',
#  'tacotalpa',
#  'onokhoy',
#  'port hardy',
#  'sao jose da coroa grande',
#  'cabo san lucas',
#  'nemuro',
#  'eyl',
#  'tiksi',
#  'hvammstangi',
#  'abu samrah',
#  'hilo',
#  'lompoc',
#  'general roca',
#  'pevek',
#  'karkaralinsk',
#  'bakchar',
#  'puerto escondido',
#  'herat',
#  'palabuhanratu',
#  'wamba',
#  'almeria',
#  'cherskiy',
#  'bengkulu',
#  'tuktoyaktuk',
#  'oyama',
#  'ketchikan',
#  'judenburg',
#  'balimo',
#  'kabompo',
#  'valparaiso',
#  'newton',
#  'marawi',
#  'sidmouth',
#  'tual',
#  'mudon',
#  'airai',
#  'sokoni',
#  'lucapa',
#  'mugur-aksy',
#  'mys shmidta',
#  'tiznit',
#  'nanortalik',
#  'adrar',
#  'souillac',
#  'warrnambool',
#  'braintree',
#  'nizhneyansk',
#  'baranchinskiy',
#  'ponta do sol',
#  'honiara',
#  'rimbey',
#  'aligudarz',
#  'narsaq',
#  'biharamulo',
#  'leshukonskoye',
#  'saint-joseph',
#  'thaba-tseka',
#  'stornoway',
#  'santiago de cuba',
#  'kodiak',
#  'colares',
#  'norman wells',
#  'fremont',
#  'kolokani',
#  'johi',
#  'sinnamary',
#  'bambous virieux',
#  'hami',
#  'dhidhdhoo',
#  'cascais',
#  'goderich',
#  'kenai',
#  'grand river south east',
#  'ishigaki',
#  'laiagam',
#  'jacareacanga',
#  'nome',
#  'batagay-alyta',
#  'qasigiannguit',
#  'olafsvik',
#  'akyab']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

count = 0
lat_list = []
long_list = []
city_name_list = []
temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []

for city in cities:
    count = count + 1
    print(city)
    try:
        query_url = url + "appid=" + api_key + "&q=" + city
        print(query_url) 
        city_json = requests.get(query_url).json()
        pprint(city_json)
        city_name = city_json["name"]
        city_name_list.append(city_name)
        wind_speed_list.append(city_json["wind"]["speed"])
        lat_list.append(city_json["coord"]["lat"])
        long_list.append(city_json["coord"]["lon"])
        temp_list.append(city_json["main"]["temp_max"])
        cloudiness_list.append(city_json["clouds"]["all"])
        humidity_list.append(city_json["main"]["humidity"])
    except:
        print("weather for city not found " + city) 

    
    
print(len(lat_list))
print(len(long_list))
print(len(city_name_list))
print(len(temp_list))
# Out:
# rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=rikitea
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1554595866,
#  'id': 4030556,
#  'main': {'grnd_level': 1015.21,
#           'humidity': 100,
#           'pressure': 1015.32,
#           'sea_level': 1015.32,
#           'temp': 298.786,
#           'temp_max': 298.786,
#           'temp_min': 298.786},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0032,
#          'sunrise': 1554563375,
#          'sunset': 1554605676},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100.503, 'speed': 5.72}}
# mataura
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=mataura
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1554595806,
#  'id': 6201424,
#  'main': {'humidity': 62,
#           'pressure': 1024,
#           'temp': 287.59,
#           'temp_max': 287.59,
#           'temp_min': 287.59},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.009,
#          'sunrise': 1554577761,
#          'sunset': 1554618246,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 329, 'gust': 3.58, 'speed': 0.45}}
# yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=yellowknife
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1554595822,
#  'id': 6185377,
#  'main': {'humidity': 57,
#           'pressure': 1012,
#           'temp': 266.59,
#           'temp_max': 267.15,
#           'temp_min': 265.37},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'message': 0.0043,
#          'sunrise': 1554554528,
#          'sunset': 1554604642,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 110, 'gust': 10.3, 'speed': 6.7}}
# bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=bredasdorp
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1554595335,
#  'id': 1015776,
#  'main': {'humidity': 82,
#           'pressure': 1016,
#           'temp': 290.45,
#           'temp_max': 291.15,
#           'temp_min': 289.82},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'message': 0.0038,
#          'sunrise': 1554612982,
#          'sunset': 1554654444,
#          'type': 1},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 150, 'speed': 3.1}}
# avarua
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=avarua
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1554593400,
#  'id': 4035715,
#  'main': {'humidity': 65,
#           'pressure': 1016,
#           'temp': 300.15,
#           'temp_max': 300.15,
#           'temp_min': 300.15},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'message': 0.0042,
#          'sunrise': 1554569273,
#          'sunset': 1554611684,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 6.2}}
# tabuk
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=tabuk
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 17.41, 'lon': 121.44},
#  'dt': 1554596160,
#  'id': 1684803,
#  'main': {'grnd_level': 922.81,
#           'humidity': 91,
#           'pressure': 1013.76,
#           'sea_level': 1013.76,
#           'temp': 294.886,
#           'temp_max': 294.886,
#           'temp_min': 294.886},
#  'name': 'Tabuk',
#  'sys': {'country': 'PH',
#          'message': 0.003,
#          'sunrise': 1554587073,
#          'sunset': 1554631691},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 203.503, 'speed': 0.87}}
# busselton
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=busselton
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1554595811,
#  'id': 2075265,
#  'main': {'humidity': 66,
#           'pressure': 1015,
#           'temp': 284.82,
#           'temp_max': 284.82,
#           'temp_min': 284.82},
#  'name': 'Busselton',
#  'rain': {'3h': 0.0275},
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'message': 0.0036,
#          'sunrise': 1554590062,
#          'sunset': 1554631625,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 154.503, 'speed': 4.57}}
# longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=longyearbyen
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 78.22, 'lon': 15.63},
#  'dt': 1554591000,
#  'id': 2729907,
#  'main': {'humidity': 57,
#           'pressure': 1021,
#           'temp': 265.15,
#           'temp_max': 265.15,
#           'temp_min': 265.15},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'NO',
#          'id': 1663,
#          'message': 0.0052,
#          'sunrise': 1554603705,
#          'sunset': 1554665838,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 8.7}}
# hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=hermanus
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1554595335,
#  'id': 3366880,
#  'main': {'humidity': 87,
#           'pressure': 1011,
#           'temp': 289.82,
#           'temp_max': 289.82,
#           'temp_min': 289.82},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'message': 0.003,
#          'sunrise': 1554613170,
#          'sunset': 1554654640,
#          'type': 3},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 134, 'gust': 6.71, 'speed': 3.13}}
# port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=port alfred
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1554595627,
#  'id': 964432,
#  'main': {'humidity': 90,
#           'pressure': 1017,
#           'temp': 289.26,
#           'temp_max': 289.26,
#           'temp_min': 289.26},
#  'name': 'Port Alfred',
#  'rain': {},
#  'sys': {'country': 'ZA',
#          'id': 2011314,
#          'message': 0.0035,
#          'sunrise': 1554611301,
#          'sunset': 1554652838,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 53.5034, 'speed': 7.62}}
# qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=qaanaaq
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 77.48, 'lon': -69.36},
#  'dt': 1554595866,
#  'id': 3831208,
#  'main': {'grnd_level': 984.73,
#           'humidity': 87,
#           'pressure': 1017.64,
#           'sea_level': 1017.64,
#           'temp': 262.536,
#           'temp_max': 262.536,
#           'temp_min': 262.536},
#  'name': 'Qaanaaq',
#  'sys': {'country': 'GL',
#          'message': 0.0039,
#          'sunrise': 1554538778,
#          'sunset': 1554598787},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 95.0034, 'speed': 4.92}}
# beloha
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=beloha
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -25.17, 'lon': 45.06},
#  'dt': 1554596161,
#  'id': 1067565,
#  'main': {'grnd_level': 999.45,
#           'humidity': 64,
#           'pressure': 1015.76,
#           'sea_level': 1015.76,
#           'temp': 298.136,
#           'temp_max': 298.136,
#           'temp_min': 298.136},
#  'name': 'Beloha',
#  'sys': {'country': 'MG',
#          'message': 0.0087,
#          'sunrise': 1554606644,
#          'sunset': 1554648775},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 75.5034, 'speed': 4.82}}
# punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=punta arenas
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1554595353,
#  'id': 3874787,
#  'main': {'humidity': 81,
#           'pressure': 996,
#           'temp': 279.96,
#           'temp_max': 280.15,
#           'temp_min': 279.82},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'message': 0.0032,
#          'sunrise': 1554549290,
#          'sunset': 1554589019,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 17}}
# soe
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=soe
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 57.91, 'lon': 26.05},
#  'dt': 1554595894,
#  'id': 587876,
#  'main': {'humidity': 69,
#           'pressure': 1017,
#           'temp': 277.42,
#           'temp_max': 279.82,
#           'temp_min': 275.15},
#  'name': 'Soe',
#  'sys': {'country': 'EE',
#          'id': 1335,
#          'message': 0.0071,
#          'sunrise': 1554607696,
#          'sunset': 1554656846,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 2.6}}
# kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kapaa
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 22.08, 'lon': -159.32},
#  'dt': 1554595693,
#  'id': 5848280,
#  'main': {'humidity': 61,
#           'pressure': 1016,
#           'temp': 299.44,
#           'temp_max': 300.15,
#           'temp_min': 298.71},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 7873,
#          'message': 0.0051,
#          'sunrise': 1554567914,
#          'sunset': 1554612822,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 7.2}}
# havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=havre-saint-pierre
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 50.23, 'lon': -63.6},
#  'dt': 1554591600,
#  'id': 5972291,
#  'main': {'humidity': 86,
#           'pressure': 1011,
#           'temp': 272.15,
#           'temp_max': 272.15,
#           'temp_min': 272.15},
#  'name': 'Havre-Saint-Pierre',
#  'sys': {'country': 'CA',
#          'id': 812,
#          'message': 0.0037,
#          'sunrise': 1554543621,
#          'sunset': 1554591179,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 6.2}}
# grafton
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=grafton
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -29.69, 'lon': 152.93},
#  'dt': 1554596008,
#  'id': 2164771,
#  'main': {'humidity': 77,
#           'pressure': 1021,
#           'temp': 295.94,
#           'temp_max': 297.59,
#           'temp_min': 294.15},
#  'name': 'Grafton',
#  'sys': {'country': 'AU',
#          'id': 9523,
#          'message': 0.0048,
#          'sunrise': 1554580897,
#          'sunset': 1554622754,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 20, 'speed': 1.5}}
# barrow
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=barrow
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1554595762,
#  'id': 3833859,
#  'main': {'grnd_level': 1004.81,
#           'humidity': 45,
#           'pressure': 1016.6,
#           'sea_level': 1016.6,
#           'temp': 291.186,
#           'temp_max': 291.186,
#           'temp_min': 291.186},
#  'name': 'Barrow',
#  'sys': {'country': 'AR',
#          'message': 0.0028,
#          'sunrise': 1554545957,
#          'sunset': 1554587226},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 326.003, 'speed': 5.37}}
# kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kloulklubed
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 7.04, 'lon': 134.26},
#  'dt': 1554594600,
#  'id': 7671223,
#  'main': {'humidity': 88,
#           'pressure': 1011,
#           'temp': 299.15,
#           'temp_max': 299.15,
#           'temp_min': 299.15},
#  'name': 'Kloulklubed',
#  'sys': {'country': 'PW',
#          'id': 7901,
#          'message': 0.0048,
#          'sunrise': 1554584308,
#          'sunset': 1554628304,
#          'type': 1},
#  'visibility': 22530,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 2.6}}
# owando
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=owando
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -0.49, 'lon': 15.91},
#  'dt': 1554596162,
#  'id': 2255542,
#  'main': {'grnd_level': 973.45,
#           'humidity': 93,
#           'pressure': 1009.16,
#           'sea_level': 1009.16,
#           'temp': 296.686,
#           'temp_max': 296.686,
#           'temp_min': 296.686},
#  'name': 'Owando',
#  'sys': {'country': 'CG',
#          'message': 0.0046,
#          'sunrise': 1554612917,
#          'sunset': 1554656491},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 313.003, 'speed': 0.92}}
# tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=tessalit
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 20.2, 'lon': 1.01},
#  'dt': 1554596018,
#  'id': 2449893,
#  'main': {'grnd_level': 953.69,
#           'humidity': 27,
#           'pressure': 1012.28,
#           'sea_level': 1012.28,
#           'temp': 291.136,
#           'temp_max': 291.136,
#           'temp_min': 291.136},
#  'name': 'Tessalit',
#  'sys': {'country': 'ML',
#          'message': 0.0037,
#          'sunrise': 1554615869,
#          'sunset': 1554660690},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 322.003, 'speed': 3.37}}
# provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=provideniya
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1554596024,
#  'id': 4031574,
#  'main': {'grnd_level': 995.61,
#           'humidity': 100,
#           'pressure': 1002.04,
#           'sea_level': 1002.04,
#           'temp': 264.936,
#           'temp_max': 264.936,
#           'temp_min': 264.936},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'message': 0.0071,
#          'sunrise': 1554654489,
#          'sunset': 1554705688},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 43.0034, 'speed': 2.57}}
# road town
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=road town
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 18.42, 'lon': -64.62},
#  'dt': 1554595932,
#  'id': 3577430,
#  'main': {'humidity': 65,
#           'pressure': 1019,
#           'temp': 298.32,
#           'temp_max': 299.15,
#           'temp_min': 297.59},
#  'name': 'Road Town',
#  'sys': {'country': 'VG',
#          'id': 8786,
#          'message': 0.0049,
#          'sunrise': 1554545318,
#          'sunset': 1554589971,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 5.7}}
# atuona
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=atuona
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1554595957,
#  'id': 4020109,
#  'main': {'grnd_level': 1009.37,
#           'humidity': 99,
#           'pressure': 1009.44,
#           'sea_level': 1009.44,
#           'temp': 301.536,
#           'temp_max': 301.536,
#           'temp_min': 301.536},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0026,
#          'sunrise': 1554563966,
#          'sunset': 1554607033},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 98.0034, 'speed': 5.82}}
# wajir
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=wajir
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 1.75, 'lon': 40.07},
#  'dt': 1554596030,
#  'id': 178443,
#  'main': {'grnd_level': 978.73,
#           'humidity': 53,
#           'pressure': 1009.4,
#           'sea_level': 1009.4,
#           'temp': 299.636,
#           'temp_max': 299.636,
#           'temp_min': 299.636},
#  'name': 'Wajir',
#  'sys': {'country': 'KE',
#          'message': 0.0032,
#          'sunrise': 1554607057,
#          'sunset': 1554650757},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110.503, 'speed': 4.02}}
# high level
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=high level
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 58.52, 'lon': -117.13},
#  'dt': 1554595560,
#  'id': 5975004,
#  'main': {'humidity': 71,
#           'pressure': 1003,
#           'temp': 273.15,
#           'temp_max': 273.15,
#           'temp_min': 273.15},
#  'name': 'High Level',
#  'sys': {'country': 'CA',
#          'id': 867,
#          'message': 0.0035,
#          'sunrise': 1554555692,
#          'sunset': 1554604797,
#          'type': 1},
#  'visibility': 3219,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 120, 'speed': 2.6}}
# attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=attawapiskat
# {'cod': '404', 'message': 'city not found'}
# weather for city not found attawapiskat
# dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=dunedin
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -45.87, 'lon': 170.5},
#  'dt': 1554595947,
#  'id': 2191562,
#  'main': {'humidity': 54,
#           'pressure': 1026,
#           'temp': 287.59,
#           'temp_max': 287.59,
#           'temp_min': 287.59},
#  'name': 'Dunedin',
#  'sys': {'country': 'NZ',
#          'id': 75281,
#          'message': 0.0036,
#          'sunrise': 1554577350,
#          'sunset': 1554617870,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 33, 'gust': 9.83, 'speed': 8.49}}
# okha
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=okha
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 53.59, 'lon': 142.95},
#  'dt': 1554595900,
#  'id': 2122614,
#  'main': {'grnd_level': 1000.25,
#           'humidity': 100,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': 269.986,
#           'temp_max': 269.986,
#           'temp_min': 269.986},
#  'name': 'Okha',
#  'sys': {'country': 'RU',
#          'message': 0.0035,
#          'sunrise': 1554580120,
#          'sunset': 1554628321},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 336.003, 'speed': 5.12}}
# albany
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=albany
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1554595870,
#  'id': 5106834,
#  'main': {'humidity': 53,
#           'pressure': 1022,
#           'temp': 282.17,
#           'temp_max': 285.15,
#           'temp_min': 278.15},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 3273,
#          'message': 0.006,
#          'sunrise': 1554546533,
#          'sunset': 1554593138,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 3.6}}
# maceio
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=maceio
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.67, 'lon': -35.74},
#  'dt': 1554591600,
#  'id': 3395981,
#  'main': {'humidity': 88,
#           'pressure': 1014,
#           'temp': 298.15,
#           'temp_max': 298.15,
#           'temp_min': 298.15},
#  'name': 'Maceio',
#  'sys': {'country': 'BR',
#          'id': 8413,
#          'message': 0.0037,
#          'sunrise': 1554539174,
#          'sunset': 1554582256,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 2.6}}
# pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=pangnirtung
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 66.15, 'lon': -65.72},
#  'dt': 1554595987,
#  'id': 6096551,
#  'main': {'grnd_level': 985.21,
#           'humidity': 79,
#           'pressure': 1004.28,
#           'sea_level': 1004.28,
#           'temp': 266.086,
#           'temp_max': 266.086,
#           'temp_min': 266.086},
#  'name': 'Pangnirtung',
#  'sys': {'country': 'CA',
#          'message': 0.0051,
#          'sunrise': 1554542258,
#          'sunset': 1554593560},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 38.5034, 'speed': 2.12}}
# aguimes
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=aguimes
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 27.91, 'lon': -15.45},
#  'dt': 1554596131,
#  'id': 2522325,
#  'main': {'humidity': 67,
#           'pressure': 1022,
#           'temp': 289.74,
#           'temp_max': 290.15,
#           'temp_min': 289.26},
#  'name': 'Aguimes',
#  'sys': {'country': 'ES',
#          'id': 2378,
#          'message': 0.006,
#          'sunrise': 1554619540,
#          'sunset': 1554664918,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 5.7}}
# ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=ushuaia
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1554591600,
#  'id': 3833367,
#  'main': {'humidity': 86,
#           'pressure': 990,
#           'temp': 276.15,
#           'temp_max': 276.15,
#           'temp_min': 276.15},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'message': 0.0083,
#          'sunrise': 1554548781,
#          'sunset': 1554588279,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 340, 'speed': 2.1}}
# ancud
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=ancud
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -41.87, 'lon': -73.83},
#  'dt': 1554595200,
#  'id': 3899695,
#  'main': {'humidity': 93,
#           'pressure': 1019,
#           'temp': 286.15,
#           'temp_max': 286.15,
#           'temp_min': 286.15},
#  'name': 'Ancud',
#  'sys': {'country': 'CL',
#          'id': 8512,
#          'message': 0.0035,
#          'sunrise': 1554549374,
#          'sunset': 1554590335,
#          'type': 1},
#  'weather': [{'description': 'light intensity drizzle',
#               'icon': '09n',
#               'id': 300,
#               'main': 'Drizzle'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 10, 'speed': 4.1}}
# cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=cidreira
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -30.17, 'lon': -50.22},
#  'dt': 1554596165,
#  'id': 3466165,
#  'main': {'grnd_level': 1007.45,
#           'humidity': 96,
#           'pressure': 1017.4,
#           'sea_level': 1017.4,
#           'temp': 293.936,
#           'temp_max': 293.936,
#           'temp_min': 293.936},
#  'name': 'Cidreira',
#  'rain': {'3h': 0.35},
#  'sys': {'country': 'BR',
#          'message': 0.0041,
#          'sunrise': 1554543254,
#          'sunset': 1554585125},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 101.503, 'speed': 3.47}}
# clarence town
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=clarence town
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -32.59, 'lon': 151.78},
#  'dt': 1554596141,
#  'id': 2171465,
#  'main': {'humidity': 57,
#           'pressure': 1019,
#           'temp': 298.8,
#           'temp_max': 300.37,
#           'temp_min': 297.04},
#  'name': 'Clarence Town',
#  'sys': {'country': 'AU',
#          'id': 9605,
#          'message': 0.0092,
#          'sunrise': 1554581276,
#          'sunset': 1554622928,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 2.1}}
# ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=ucluelet
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 48.94, 'lon': -125.55},
#  'dt': 1554595757,
#  'id': 6171633,
#  'main': {'humidity': 81,
#           'pressure': 1005,
#           'temp': 281.34,
#           'temp_max': 283.71,
#           'temp_min': 279.26},
#  'name': 'Ucluelet',
#  'sys': {'country': 'CA',
#          'id': 735,
#          'message': 0.0053,
#          'sunrise': 1554558559,
#          'sunset': 1554605971,
#          'type': 1},
#  'visibility': 12874,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 170, 'gust': 11.3, 'speed': 7.7}}
# saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=saldanha
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 41.42, 'lon': -6.55},
#  'dt': 1554595879,
#  'id': 2737599,
#  'main': {'grnd_level': 933.61,
#           'humidity': 94,
#           'pressure': 1008.04,
#           'sea_level': 1008.04,
#           'temp': 276.986,
#           'temp_max': 276.986,
#           'temp_min': 276.986},
#  'name': 'Saldanha',
#  'sys': {'country': 'PT',
#          'message': 0.0038,
#          'sunrise': 1554616790,
#          'sunset': 1554663397},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 261.503, 'speed': 3.12}}
# kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kavaratti
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 10.57, 'lon': 72.64},
#  'dt': 1554595938,
#  'id': 1267390,
#  'main': {'grnd_level': 1010.33,
#           'humidity': 100,
#           'pressure': 1010.32,
#           'sea_level': 1010.32,
#           'temp': 302.086,
#           'temp_max': 302.086,
#           'temp_min': 302.086},
#  'name': 'Kavaratti',
#  'sys': {'country': 'IN',
#          'message': 0.0036,
#          'sunrise': 1554598988,
#          'sunset': 1554643195},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320.503, 'speed': 3.92}}
# kachug
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kachug
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 53.96, 'lon': 105.89},
#  'dt': 1554595974,
#  'id': 2023333,
#  'main': {'grnd_level': 925.13,
#           'humidity': 72,
#           'pressure': 1024.08,
#           'sea_level': 1024.08,
#           'temp': 262.286,
#           'temp_max': 262.286,
#           'temp_min': 262.286},
#  'name': 'Kachug',
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1554588967,
#          'sunset': 1554637259},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 88.0034, 'speed': 1.17}}
# abha
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=abha
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.22, 'lon': 42.5},
#  'dt': 1554591600,
#  'id': 110690,
#  'main': {'humidity': 59,
#           'pressure': 1025,
#           'temp': 290.15,
#           'temp_max': 290.15,
#           'temp_min': 290.15},
#  'name': 'Abha',
#  'sys': {'country': 'SA',
#          'id': 7396,
#          'message': 0.004,
#          'sunrise': 1554605982,
#          'sunset': 1554650665,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 5.1}}
# thompson
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=thompson
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1554591600,
#  'id': 6165406,
#  'main': {'humidity': 50,
#           'pressure': 1020,
#           'temp': 273.15,
#           'temp_max': 273.15,
#           'temp_min': 273.15},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'message': 0.0056,
#          'sunrise': 1554551366,
#          'sunset': 1554599875,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 2.6}}
# jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=jamestown
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1554595954,
#  'id': 2069194,
#  'main': {'grnd_level': 961.61,
#           'humidity': 47,
#           'pressure': 1019.4,
#           'sea_level': 1019.4,
#           'temp': 292.386,
#           'temp_max': 292.386,
#           'temp_min': 292.386},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0029,
#          'sunrise': 1554584463,
#          'sunset': 1554626066},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 299.503, 'speed': 3.42}}
# ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=ostrovnoy
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 68.05, 'lon': 39.51},
#  'dt': 1554596166,
#  'id': 556268,
#  'main': {'grnd_level': 992.81,
#           'humidity': 92,
#           'pressure': 1019.08,
#           'sea_level': 1019.08,
#           'temp': 270.436,
#           'temp_max': 270.436,
#           'temp_min': 270.436},
#  'name': 'Ostrovnoy',
#  'sys': {'country': 'RU',
#          'message': 0.0038,
#          'sunrise': 1554602821,
#          'sunset': 1554655262},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 246.503, 'speed': 3.47}}
# shache
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=shache
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 38.42, 'lon': 77.24},
#  'dt': 1554596124,
#  'id': 1280037,
#  'main': {'humidity': 66,
#           'pressure': 1028,
#           'temp': 288.71,
#           'temp_max': 288.71,
#           'temp_min': 288.71},
#  'name': 'Shache',
#  'sys': {'country': 'CN',
#          'id': 2003783,
#          'message': 0.0038,
#          'sunrise': 1554596859,
#          'sunset': 1554643117,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 291.503, 'speed': 6.82}}
# huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=huarmey
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -10.07, 'lon': -78.15},
#  'dt': 1554596027,
#  'id': 3939168,
#  'main': {'grnd_level': 942.73,
#           'humidity': 72,
#           'pressure': 1011.88,
#           'sea_level': 1011.88,
#           'temp': 294.236,
#           'temp_max': 294.236,
#           'temp_min': 294.236},
#  'name': 'Huarmey',
#  'sys': {'country': 'PE',
#          'message': 0.0031,
#          'sunrise': 1554549363,
#          'sunset': 1554592420},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 184.503, 'speed': 1.42}}
# pallasovka
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=pallasovka
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 50.04, 'lon': 46.89},
#  'dt': 1554596166,
#  'id': 513042,
#  'main': {'grnd_level': 1016.33,
#           'humidity': 100,
#           'pressure': 1020.76,
#           'sea_level': 1020.76,
#           'temp': 281.736,
#           'temp_max': 281.736,
#           'temp_min': 281.736},
#  'name': 'Pallasovka',
#  'rain': {'3h': 1.21},
#  'sys': {'country': 'RU',
#          'message': 0.0121,
#          'sunrise': 1554603428,
#          'sunset': 1554651113},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 277.003, 'speed': 0.62}}
# hobart
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=hobart
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1554595821,
#  'id': 2163355,
#  'main': {'humidity': 48,
#           'pressure': 1010,
#           'temp': 289.78,
#           'temp_max': 290.93,
#           'temp_min': 288.71},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0068,
#          'sunrise': 1554582768,
#          'sunset': 1554623571,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 7.2}}
# malakisi
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=malakisi
# {'cod': '404', 'message': 'city not found'}
# weather for city not found malakisi
# touros
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=touros
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -5.2, 'lon': -35.46},
#  'dt': 1554591600,
#  'id': 3386213,
#  'main': {'humidity': 88,
#           'pressure': 1014,
#           'temp': 300.15,
#           'temp_max': 300.15,
#           'temp_min': 300.15},
#  'name': 'Touros',
#  'sys': {'country': 'BR',
#          'id': 8452,
#          'message': 0.0125,
#          'sunrise': 1554538986,
#          'sunset': 1554582309,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 2.1}}
# arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=arraial do cabo
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.02},
#  'dt': 1554595902,
#  'id': 3471451,
#  'main': {'grnd_level': 1013.21,
#           'humidity': 90,
#           'pressure': 1014.2,
#           'sea_level': 1014.2,
#           'temp': 300.036,
#           'temp_max': 300.036,
#           'temp_min': 300.036},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'message': 0.0048,
#          'sunrise': 1554541057,
#          'sunset': 1554583387},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 51.0034, 'speed': 2.12}}
# monroe
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=monroe
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.91, 'lon': -83.4},
#  'dt': 1554596004,
#  'id': 5002344,
#  'main': {'humidity': 76,
#           'pressure': 1021,
#           'temp': 288.14,
#           'temp_max': 291.48,
#           'temp_min': 283.71},
#  'name': 'Monroe',
#  'sys': {'country': 'US',
#          'id': 6074,
#          'message': 0.0123,
#          'sunrise': 1554548886,
#          'sunset': 1554595416,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 3.1}}
# belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=belushya guba
# {'cod': '404', 'message': 'city not found'}
# weather for city not found belushya guba
# ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=ilulissat
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 69.22, 'lon': -51.1},
#  'dt': 1554591000,
#  'id': 3423146,
#  'main': {'humidity': 44,
#           'pressure': 1013,
#           'temp': 277.15,
#           'temp_max': 277.15,
#           'temp_min': 277.15},
#  'name': 'Ilulissat',
#  'sys': {'country': 'GL',
#          'id': 165,
#          'message': 0.0049,
#          'sunrise': 1554538079,
#          'sunset': 1554590722,
#          'type': 1},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'gust': 19.5, 'speed': 14.4}}
# taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=taolanaro
# {'cod': '404', 'message': 'city not found'}
# weather for city not found taolanaro
# estelle
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=estelle
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 32.87, 'lon': -97.01},
#  'dt': 1554596158,
#  'id': 4671240,
#  'main': {'humidity': 82,
#           'pressure': 1011,
#           'temp': 291.7,
#           'temp_max': 292.59,
#           'temp_min': 290.93},
#  'name': 'Estelle',
#  'sys': {'country': 'US',
#          'id': 3783,
#          'message': 0.0104,
#          'sunrise': 1554552572,
#          'sunset': 1554598261,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 3.6}}
# chuy
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=chuy
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -33.69, 'lon': -53.46},
#  'dt': 1554596002,
#  'id': 3443061,
#  'main': {'grnd_level': 1018.73,
#           'humidity': 87,
#           'pressure': 1020.2,
#           'sea_level': 1020.2,
#           'temp': 290.686,
#           'temp_max': 290.686,
#           'temp_min': 290.686},
#  'name': 'Chuy',
#  'sys': {'country': 'UY',
#          'message': 0.0032,
#          'sunrise': 1554544155,
#          'sunset': 1554585779},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 126.503, 'speed': 2.32}}
# illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# weather for city not found illoqqortoormiut
# carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=carnarvon
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -30.97, 'lon': 22.13},
#  'dt': 1554595865,
#  'id': 1014034,
#  'main': {'grnd_level': 864.33,
#           'humidity': 76,
#           'pressure': 1015.44,
#           'sea_level': 1015.44,
#           'temp': 281.886,
#           'temp_max': 281.886,
#           'temp_min': 281.886},
#  'name': 'Carnarvon',
#  'sys': {'country': 'ZA',
#          'message': 0.0048,
#          'sunrise': 1554612347,
#          'sunset': 1554654076},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 97.0034, 'speed': 2.97}}
# hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=hamilton
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 32.3, 'lon': -64.78},
#  'dt': 1554595261,
#  'id': 3573197,
#  'main': {'humidity': 88,
#           'pressure': 1022,
#           'temp': 292.83,
#           'temp_max': 293.15,
#           'temp_min': 292.59},
#  'name': 'Hamilton',
#  'sys': {'country': 'BM',
#          'id': 8816,
#          'message': 0.005,
#          'sunrise': 1554544867,
#          'sunset': 1554590499,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 1.5}}
# inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=inhambane
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -23.87, 'lon': 35.38},
#  'dt': 1554596169,
#  'id': 1045114,
#  'main': {'grnd_level': 1013.45,
#           'humidity': 100,
#           'pressure': 1017.4,
#           'sea_level': 1017.4,
#           'temp': 297.586,
#           'temp_max': 297.586,
#           'temp_min': 297.586},
#  'name': 'Inhambane',
#  'rain': {'3h': 0.3625},
#  'sys': {'country': 'MZ',
#          'message': 0.0049,
#          'sunrise': 1554608926,
#          'sunset': 1554651138},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 164.003, 'speed': 3.32}}
# dondo
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=dondo
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -19.62, 'lon': 34.74},
#  'dt': 1554591600,
#  'id': 1024696,
#  'main': {'humidity': 100,
#           'pressure': 1016,
#           'temp': 297.15,
#           'temp_max': 297.15,
#           'temp_min': 297.15},
#  'name': 'Dondo',
#  'sys': {'country': 'MZ',
#          'id': 2194,
#          'message': 0.0041,
#          'sunrise': 1554608948,
#          'sunset': 1554651424,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 1.5}}
# tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=tasiilaq
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1554594600,
#  'id': 3424607,
#  'main': {'humidity': 46,
#           'pressure': 1026,
#           'temp': 272.15,
#           'temp_max': 272.15,
#           'temp_min': 272.15},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'message': 0.0042,
#          'sunrise': 1554535638,
#          'sunset': 1554586704,
#          'type': 1},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'gust': 31.4, 'speed': 17.5}}
# katsiveli
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=katsiveli
# {'cod': '404', 'message': 'city not found'}
# weather for city not found katsiveli
# haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=haines junction
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 60.75, 'lon': -137.51},
#  'dt': 1554596005,
#  'id': 5969025,
#  'main': {'grnd_level': 869.45,
#           'humidity': 71,
#           'pressure': 994.44,
#           'sea_level': 994.44,
#           'temp': 275.836,
#           'temp_max': 275.836,
#           'temp_min': 275.836},
#  'name': 'Haines Junction',
#  'sys': {'country': 'CA',
#          'message': 0.0042,
#          'sunrise': 1554560301,
#          'sunset': 1554609968},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 216.003, 'speed': 1.22}}
# colgong
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=colgong
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 25.27, 'lon': 87.22},
#  'dt': 1554596049,
#  'id': 1273856,
#  'main': {'grnd_level': 1004.33,
#           'humidity': 92,
#           'pressure': 1009.6,
#           'sea_level': 1009.6,
#           'temp': 292.536,
#           'temp_max': 292.536,
#           'temp_min': 292.536},
#  'name': 'Colgong',
#  'rain': {'3h': 0.1075},
#  'sys': {'country': 'IN',
#          'message': 0.0039,
#          'sunrise': 1554595016,
#          'sunset': 1554640170},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 62.0034, 'speed': 3.77}}
# karaul
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=karaul
# {'cod': '404', 'message': 'city not found'}
# weather for city not found karaul
# awjilah
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=awjilah
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.14, 'lon': 21.3},
#  'dt': 1554596170,
#  'id': 88533,
#  'main': {'grnd_level': 1006.57,
#           'humidity': 58,
#           'pressure': 1010.04,
#           'sea_level': 1010.04,
#           'temp': 290.636,
# ...
#           'temp': 271.886,
#           'temp_max': 271.886,
#           'temp_min': 271.886},
#  'name': 'Thaba-Tseka',
#  'sys': {'country': 'LS',
#          'message': 0.0033,
#          'sunrise': 1554610740,
#          'sunset': 1554652573},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 339.503, 'speed': 0.87}}
# stornoway
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=stornoway
# {'cod': '404', 'message': 'city not found'}
# weather for city not found stornoway
# santiago de cuba
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=santiago de cuba
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 20.03, 'lon': -75.83},
#  'dt': 1554591360,
#  'id': 3536729,
#  'main': {'humidity': 69,
#           'pressure': 1016,
#           'temp': 300.76,
#           'temp_max': 301.15,
#           'temp_min': 300.15},
#  'name': 'Santiago de Cuba',
#  'sys': {'country': 'CU',
#          'id': 7240,
#          'message': 0.0039,
#          'sunrise': 1554547956,
#          'sunset': 1554592713,
#          'type': 1},
#  'visibility': 9000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 3.1}}
# kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kodiak
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1554596009,
#  'id': 4407665,
#  'main': {'humidity': 18,
#           'pressure': 1010,
#           'temp': 294.49,
#           'temp_max': 295.37,
#           'temp_min': 293.71},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 4022,
#          'message': 0.0052,
#          'sunrise': 1554551711,
#          'sunset': 1554598043,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 150, 'speed': 4.1}}
# colares
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=colares
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 38.8, 'lon': -9.45},
#  'dt': 1554596171,
#  'id': 2269142,
#  'main': {'humidity': 81,
#           'pressure': 1012,
#           'temp': 285.27,
#           'temp_max': 286.48,
#           'temp_min': 283.71},
#  'name': 'Colares',
#  'sys': {'country': 'PT',
#          'id': 6901,
#          'message': 0.0039,
#          'sunrise': 1554617623,
#          'sunset': 1554663955,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 4.1}}
# norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=norman wells
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 65.28, 'lon': -126.83},
#  'dt': 1554591600,
#  'id': 6089245,
#  'main': {'humidity': 63,
#           'pressure': 1004,
#           'temp': 271.15,
#           'temp_max': 271.15,
#           'temp_min': 271.15},
#  'name': 'Norman Wells',
#  'sys': {'country': 'CA',
#          'id': 951,
#          'message': 0.0037,
#          'sunrise': 1554557048,
#          'sunset': 1554608097,
#          'type': 1},
#  'visibility': 48279,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 6.2}}
# fremont
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=fremont
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 37.55, 'lon': -121.99},
#  'dt': 1554595870,
#  'id': 5350734,
#  'main': {'humidity': 59,
#           'pressure': 1019,
#           'temp': 292.41,
#           'temp_max': 294.26,
#           'temp_min': 290.93},
#  'name': 'Fremont',
#  'sys': {'country': 'US',
#          'id': 4774,
#          'message': 0.009,
#          'sunrise': 1554558356,
#          'sunset': 1554604466,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 4.1}}
# kolokani
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kolokani
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 13.58, 'lon': -8.03},
#  'dt': 1554596208,
#  'id': 2454955,
#  'main': {'grnd_level': 967.37,
#           'humidity': 28,
#           'pressure': 1011.2,
#           'sea_level': 1011.2,
#           'temp': 301.636,
#           'temp_max': 301.636,
#           'temp_min': 301.636},
#  'name': 'Kolokani',
#  'sys': {'country': 'ML',
#          'message': 0.0031,
#          'sunrise': 1554618250,
#          'sunset': 1554662647},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 8.50336, 'speed': 6.12}}
# johi
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=johi
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 26.69, 'lon': 67.61},
#  'dt': 1554596209,
#  'id': 1175678,
#  'main': {'grnd_level': 995.13,
#           'humidity': 32,
#           'pressure': 1004.32,
#           'sea_level': 1004.32,
#           'temp': 300.536,
#           'temp_max': 300.536,
#           'temp_min': 300.536},
#  'name': 'Johi',
#  'sys': {'country': 'PK',
#          'message': 0.0096,
#          'sunrise': 1554599667,
#          'sunset': 1554644930},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 252.003, 'speed': 3.87}}
# sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=sinnamary
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 5.38, 'lon': -52.96},
#  'dt': 1554596209,
#  'id': 3380290,
#  'main': {'grnd_level': 1013.13,
#           'humidity': 100,
#           'pressure': 1014.44,
#           'sea_level': 1014.44,
#           'temp': 298.886,
#           'temp_max': 298.886,
#           'temp_min': 298.886},
#  'name': 'Sinnamary',
#  'rain': {'3h': 0.6025},
#  'sys': {'country': 'GF',
#          'message': 0.004,
#          'sunrise': 1554542900,
#          'sunset': 1554586794},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 63.5034, 'speed': 5.67}}
# bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=bambous virieux
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -20.34, 'lon': 57.76},
#  'dt': 1554595740,
#  'id': 1106677,
#  'main': {'humidity': 69,
#           'pressure': 1016,
#           'temp': 299.17,
#           'temp_max': 300.15,
#           'temp_min': 298.15},
#  'name': 'Bambous Virieux',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'message': 0.0032,
#          'sunrise': 1554603444,
#          'sunset': 1554645881,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 5.1}}
# hami
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=hami
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 42.84, 'lon': 93.51},
#  'dt': 1554596076,
#  'id': 1529484,
#  'main': {'grnd_level': 930.57,
#           'humidity': 54,
#           'pressure': 1010.96,
#           'sea_level': 1010.96,
#           'temp': 284.586,
#           'temp_max': 284.586,
#           'temp_min': 284.586},
#  'name': 'Hami',
#  'sys': {'country': 'CN',
#          'message': 0.0037,
#          'sunrise': 1554592724,
#          'sunset': 1554639443},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 89.5034, 'speed': 0.77}}
# dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=dhidhdhoo
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 6.88, 'lon': 73.1},
#  'dt': 1554596209,
#  'id': 1337612,
#  'main': {'grnd_level': 1010.57,
#           'humidity': 100,
#           'pressure': 1010.64,
#           'sea_level': 1010.64,
#           'temp': 301.786,
#           'temp_max': 301.786,
#           'temp_min': 301.786},
#  'name': 'Dhidhdhoo',
#  'sys': {'country': 'MV',
#          'message': 0.0035,
#          'sunrise': 1554598986,
#          'sunset': 1554642977},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 323.503, 'speed': 1.62}}
# cascais
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=cascais
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 38.7, 'lon': -9.42},
#  'dt': 1554595925,
#  'id': 2269594,
#  'main': {'humidity': 81,
#           'pressure': 1012,
#           'temp': 285.33,
#           'temp_max': 286.48,
#           'temp_min': 284.15},
#  'name': 'Cascais',
#  'sys': {'country': 'PT',
#          'id': 6901,
#          'message': 0.005,
#          'sunrise': 1554617621,
#          'sunset': 1554663943,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 4.1}}
# goderich
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=goderich
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.74, 'lon': -81.71},
#  'dt': 1554595945,
#  'id': 5962442,
#  'main': {'humidity': 80,
#           'pressure': 1023,
#           'temp': 280.58,
#           'temp_max': 282.59,
#           'temp_min': 278.15},
#  'name': 'Goderich',
#  'rain': {},
#  'sys': {'country': 'CA',
#          'id': 2008803,
#          'message': 0.0038,
#          'sunrise': 1554548380,
#          'sunset': 1554595111,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 54, 'gust': 1.34, 'speed': 0.89}}
# kenai
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=kenai
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 60.55, 'lon': -151.26},
#  'dt': 1554596165,
#  'id': 5866063,
#  'main': {'humidity': 60,
#           'pressure': 988,
#           'temp': 278.77,
#           'temp_max': 279.82,
#           'temp_min': 277.04},
#  'name': 'Kenai',
#  'sys': {'country': 'US',
#          'id': 7680,
#          'message': 0.0045,
#          'sunrise': 1554563620,
#          'sunset': 1554613248,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'gust': 13.4, 'speed': 10.3}}
# grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=grand river south east
# {'cod': '404', 'message': 'city not found'}
# weather for city not found grand river south east
# ishigaki
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=ishigaki
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 24.34, 'lon': 124.16},
#  'dt': 1554591600,
#  'id': 1861416,
#  'main': {'humidity': 94,
#           'pressure': 1012,
#           'temp': 296.15,
#           'temp_max': 296.15,
#           'temp_min': 296.15},
#  'name': 'Ishigaki',
#  'sys': {'country': 'JP',
#          'id': 8139,
#          'message': 0.0048,
#          'sunrise': 1554586189,
#          'sunset': 1554631269,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1}}
# laiagam
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=laiagam
# {'cod': '404', 'message': 'city not found'}
# weather for city not found laiagam
# jacareacanga
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=jacareacanga
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': -6.22, 'lon': -57.76},
#  'dt': 1554596210,
#  'id': 3397763,
#  'main': {'grnd_level': 1000.25,
#           'humidity': 92,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 298.036,
#           'temp_max': 298.036,
#           'temp_min': 298.036},
#  'name': 'Jacareacanga',
#  'rain': {'3h': 4.2775},
#  'sys': {'country': 'BR',
#          'message': 0.0032,
#          'sunrise': 1554544365,
#          'sunset': 1554587632},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 162.503, 'speed': 0.77}}
# nome
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=nome
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 30.04, 'lon': -94.42},
#  'dt': 1554596009,
#  'id': 4732862,
#  'main': {'humidity': 88,
#           'pressure': 1013,
#           'temp': 296.33,
#           'temp_max': 297.59,
#           'temp_min': 294.82},
#  'name': 'Nome',
#  'sys': {'country': 'US',
#          'id': 3476,
#          'message': 0.004,
#          'sunrise': 1554552064,
#          'sunset': 1554597526,
#          'type': 1},
#  'visibility': 6437,
#  'weather': [{'description': 'drizzle',
#               'icon': '09n',
#               'id': 301,
#               'main': 'Drizzle'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'},
#              {'description': 'haze', 'icon': '50n', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 140, 'speed': 1.5}}
# batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=batagay-alyta
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 67.8, 'lon': 130.41},
#  'dt': 1554595982,
#  'id': 2027042,
#  'main': {'grnd_level': 929.13,
#           'humidity': 81,
#           'pressure': 1019.32,
#           'sea_level': 1019.32,
#           'temp': 267.036,
#           'temp_max': 267.036,
#           'temp_min': 267.036},
#  'name': 'Batagay-Alyta',
#  'sys': {'country': 'RU',
#          'message': 0.0031,
#          'sunrise': 1554581128,
#          'sunset': 1554633331},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 301.003, 'speed': 1.87}}
# qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=qasigiannguit
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 68.82, 'lon': -51.19},
#  'dt': 1554594600,
#  'id': 3420768,
#  'main': {'humidity': 47,
#           'pressure': 1013,
#           'temp': 276.15,
#           'temp_max': 276.15,
#           'temp_min': 276.15},
#  'name': 'Qasigiannguit',
#  'sys': {'country': 'GL',
#          'id': 165,
#          'message': 0.0037,
#          'sunrise': 1554538200,
#          'sunset': 1554590644,
#          'type': 1},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 15.4}}
# olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=olafsvik
# {'cod': '404', 'message': 'city not found'}
# weather for city not found olafsvik
# akyab
# http://api.openweathermap.org/data/2.5/weather?appid=8836da40ed8c90ca865cb0b966c11cb8&q=akyab
# {'cod': '404', 'message': 'city not found'}
# weather for city not found akyab
# 256
# 256
# 256
# 256

# %%
weather_dict={"City":city_name_list,"Cloudiness":cloudiness_list,
            "Humidity":humidity_list,"Latitude":lat_list,"Longitude":long_list,"Max_temp":temp_list,
            "Wind_speed":wind_speed_list}
weather_dict
# Out:
# {'City': ['Rikitea',
#   'Mataura',
#   'Yellowknife',
#   'Bredasdorp',
#   'Avarua',
#   'Tabuk',
#   'Busselton',
#   'Longyearbyen',
#   'Hermanus',
#   'Port Alfred',
#   'Qaanaaq',
#   'Beloha',
#   'Punta Arenas',
#   'Soe',
#   'Kapaa',
#   'Havre-Saint-Pierre',
#   'Grafton',
#   'Barrow',
#   'Kloulklubed',
#   'Owando',
#   'Tessalit',
#   'Provideniya',
#   'Road Town',
#   'Atuona',
#   'Wajir',
#   'High Level',
#   'Dunedin',
#   'Okha',
#   'Albany',
#   'Maceio',
#   'Pangnirtung',
#   'Aguimes',
#   'Ushuaia',
#   'Ancud',
#   'Cidreira',
#   'Clarence Town',
#   'Ucluelet',
#   'Saldanha',
#   'Kavaratti',
#   'Kachug',
#   'Abha',
#   'Thompson',
#   'Jamestown',
#   'Ostrovnoy',
#   'Shache',
#   'Huarmey',
#   'Pallasovka',
#   'Hobart',
#   'Touros',
#   'Arraial do Cabo',
#   'Monroe',
#   'Ilulissat',
#   'Estelle',
#   'Chuy',
#   'Carnarvon',
#   'Hamilton',
#   'Inhambane',
#   'Dondo',
#   'Tasiilaq',
#   'Haines Junction',
#   'Colgong',
#   'Awjilah',
#   'Aqtobe',
#   'Egvekinot',
#   'Fort Nelson',
#   'Butaritari',
#   'Lavrentiya',
#   'Esmeraldas',
#   'Tuatapere',
#   'Puerto Ayora',
#   'Katsuura',
#   'Kutum',
#   'Nuevo Progreso',
#   'Fortuna',
#   'Shahpura',
#   'Castro',
#   'Port Elizabeth',
#   'Pierre',
#   'Santa Cruz de la Palma',
#   'Vaini',
#   'Petropavlovsk-Kamchatskiy',
#   'Hithadhoo',
#   'Rawson',
#   'New Norfolk',
#   'Biltine',
#   'Smithers',
#   'Cape Town',
#   'Santa Cruz',
#   'Fereydun Kenar',
#   'Hachinohe',
#   'Nikolskoye',
#   'Ribeira Grande',
#   'Channel-Port aux Basques',
#   'Harper',
#   'Khatanga',
#   'Kailua',
#   'Kronach',
#   'Bluff',
#   'Bandarbeyla',
#   'Naifaru',
#   'Georgetown',
#   'Gazanjyk',
#   'Caconda',
#   'Boaco',
#   'Naples',
#   'Mar del Plata',
#   'San Roque',
#   'Sept-Iles',
#   'Dulce Grande',
#   'Roros',
#   'Lebu',
#   'San Patricio',
#   'Upernavik',
#   'Severo-Kurilsk',
#   'Forbes',
#   'Sur',
#   'Los Lunas',
#   'Port Hawkesbury',
#   'Mahebourg',
#   'High Prairie',
#   'Nabire',
#   'Leningradskiy',
#   'Pisco',
#   'Kaitangata',
#   'Esperance',
#   'Pampa',
#   'Laguna',
#   'Cervo',
#   'Kuybysheve',
#   'Bethel',
#   'North Bend',
#   'Vila Velha',
#   'Sebring',
#   'Auki',
#   'Taltal',
#   'Saint-Philippe',
#   'Victoria',
#   'Makakilo City',
#   'Lubin',
#   'Mehamn',
#   'Marienburg',
#   'San Cristobal',
#   'Torbay',
#   'Hobyo',
#   'Sibolga',
#   'Sorland',
#   'Avera',
#   'Palauig',
#   'West Odessa',
#   'Geraldton',
#   'Dikson',
#   'Gat',
#   'Epe',
#   'Maricaban',
#   'Lagoa',
#   'Viedma',
#   'Bathsheba',
#   'Hayward',
#   'Doha',
#   'Okhotsk',
#   'Novyy Urengoy',
#   'Kavieng',
#   'Kruisfontein',
#   'Sao Filipe',
#   'Stargard Szczecinski',
#   'Saskylakh',
#   'San Marcos',
#   'Coquimbo',
#   'Byron Bay',
#   'Christchurch',
#   'Dolores',
#   'Panguna',
#   'Sterling',
#   'Comarapa',
#   'Storforshei',
#   'Nantucket',
#   'Fairfield',
#   'Hasaki',
#   'Cap-aux-Meules',
#   'Salinopolis',
#   'Pangai',
#   'Sibu',
#   'Kataysk',
#   'Bajitpur',
#   'Usinsk',
#   'La Orilla',
#   'Jalu',
#   'Tacotalpa',
#   'Onokhoy',
#   'Port Hardy',
#   'Sao Jose da Coroa Grande',
#   'Cabo San Lucas',
#   'Nemuro',
#   'Eyl',
#   'Tiksi',
#   'Abu Samrah',
#   'Hilo',
#   'Lompoc',
#   'General Roca',
#   'Pevek',
#   'Bakchar',
#   'Puerto Escondido',
#   'Herat',
#   'Wamba',
#   'Almeria',
#   'Cherskiy',
#   'Tuktoyaktuk',
#   'Oyama',
#   'Ketchikan',
#   'Judenburg',
#   'Kabompo',
#   'Valparaiso',
#   'Newton',
#   'Marawi',
#   'Sidmouth',
#   'Tual',
#   'Mudon',
#   'Airai',
#   'Sokoni',
#   'Lucapa',
#   'Mugur-Aksy',
#   'Tiznit',
#   'Nanortalik',
#   'Adrar',
#   'Souillac',
#   'Warrnambool',
#   'Braintree',
#   'Baranchinskiy',
#   'Ponta do Sol',
#   'Honiara',
#   'Rimbey',
#   'Aligudarz',
#   'Narsaq',
#   'Biharamulo',
#   'Leshukonskoye',
#   'Saint-Joseph',
#   'Thaba-Tseka',
#   'Santiago de Cuba',
#   'Kodiak',
#   'Colares',
#   'Norman Wells',
#   'Fremont',
#   'Kolokani',
#   'Johi',
#   'Sinnamary',
#   'Bambous Virieux',
#   'Hami',
#   'Dhidhdhoo',
#   'Cascais',
#   'Goderich',
#   'Kenai',
#   'Ishigaki',
#   'Jacareacanga',
#   'Nome',
#   'Batagay-Alyta',
#   'Qasigiannguit'],
#  'Cloudiness': [24,
#   0,
#   90,
#   0,
#   48,
#   20,
#   8,
#   20,
#   48,
#   8,
#   80,
#   0,
#   20,
#   12,
#   75,
#   40,
#   0,
#   0,
#   90,
#   44,
#   0,
#   36,
#   1,
#   20,
#   48,
#   90,
#   0,
#   80,
#   20,
#   0,
#   88,
#   20,
#   90,
#   90,
#   100,
#   0,
#   90,
#   80,
#   0,
#   0,
#   0,
#   40,
#   0,
#   76,
#   0,
#   20,
#   92,
#   75,
#   40,
#   12,
#   1,
#   68,
#   75,
#   92,
#   0,
#   75,
#   92,
#   20,
#   92,
#   0,
#   92,
#   0,
#   0,
#   20,
#   90,
#   80,
#   24,
#   0,
#   0,
#   20,
#   75,
#   0,
#   1,
#   20,
#   0,
#   90,
#   1,
#   1,
#   20,
#   0,
#   40,
#   0,
#   0,
#   75,
#   0,
#   90,
#   0,
#   75,
#   88,
#   75,
#   0,
#   68,
#   92,
#   1,
#   88,
#   40,
#   0,
#   0,
#   0,
#   48,
#   20,
#   8,
#   56,
#   40,
#   40,
#   0,
#   75,
#   75,
#   5,
#   76,
#   0,
#   32,
#   0,
#   92,
#   0,
#   20,
#   40,
#   90,
#   75,
#   80,
#   68,
#   12,
#   0,
#   0,
#   20,
#   1,
#   5,
#   48,
#   8,
#   1,
#   90,
#   75,
#   40,
#   0,
#   0,
#   1,
#   75,
#   1,
#   0,
#   76,
#   0,
#   75,
#   90,
#   24,
#   92,
#   12,
#   90,
#   8,
#   1,
#   75,
#   80,
#   24,
#   0,
#   80,
#   40,
#   0,
#   40,
#   90,
#   0,
#   24,
#   92,
#   92,
#   0,
#   0,
#   0,
#   44,
#   75,
#   0,
#   0,
#   92,
#   0,
#   24,
#   20,
#   12,
#   76,
#   1,
#   75,
#   75,
#   75,
#   76,
#   0,
#   75,
#   0,
#   75,
#   0,
#   32,
#   20,
#   5,
#   0,
#   90,
#   48,
#   5,
#   20,
#   20,
#   0,
#   88,
#   90,
#   1,
#   0,
#   0,
#   64,
#   20,
#   0,
#   20,
#   0,
#   0,
#   40,
#   20,
#   90,
#   20,
#   68,
#   1,
#   40,
#   64,
#   24,
#   44,
#   0,
#   0,
#   24,
#   56,
#   76,
#   8,
#   68,
#   0,
#   20,
#   0,
#   75,
#   0,
#   24,
#   80,
#   75,
#   48,
#   36,
#   8,
#   32,
#   90,
#   8,
#   40,
#   1,
#   20,
#   40,
#   90,
#   0,
#   0,
#   100,
#   75,
#   80,
#   0,
#   20,
#   0,
#   20,
#   40,
#   32,
#   90,
#   48,
#   68],
#  'Humidity': [100,
#   62,
#   57,
#   82,
#   65,
#   91,
#   66,
#   57,
#   87,
#   90,
#   87,
#   64,
#   81,
#   69,
#   61,
#   86,
#   77,
#   45,
#   88,
#   93,
#   27,
#   100,
#   65,
#   99,
#   53,
#   71,
#   54,
#   100,
#   53,
#   88,
#   79,
#   67,
#   86,
#   93,
#   96,
#   57,
#   81,
#   94,
#   100,
#   72,
#   59,
#   50,
#   47,
#   92,
#   66,
#   72,
#   100,
#   48,
#   88,
#   90,
#   76,
#   44,
#   82,
#   87,
#   76,
#   88,
#   100,
#   100,
#   46,
#   71,
#   92,
#   58,
#   92,
#   78,
#   74,
#   100,
#   100,
#   78,
#   62,
#   78,
#   66,
#   30,
#   48,
#   54,
#   72,
#   93,
#   71,
#   68,
#   72,
#   88,
#   55,
#   100,
#   35,
#   48,
#   55,
#   43,
#   72,
#   77,
#   95,
#   45,
#   87,
#   100,
#   92,
#   57,
#   94,
#   69,
#   75,
#   51,
#   100,
#   100,
#   78,
#   88,
#   89,
#   62,
#   83,
#   35,
#   77,
#   74,
#   4,
#   86,
#   67,
#   79,
#   74,
#   93,
#   69,
#   80,
#   22,
#   93,
#   69,
#   93,
#   84,
#   94,
#   78,
#   44,
#   74,
#   23,
#   26,
#   97,
#   77,
#   48,
#   82,
#   78,
#   58,
#   45,
#   77,
#   86,
#   88,
#   58,
#   87,
#   88,
#   66,
#   77,
#   59,
#   85,
#   100,
#   100,
#   88,
#   94,
#   11,
#   55,
#   100,
#   60,
#   81,
#   100,
#   71,
#   39,
#   69,
#   59,
#   61,
#   70,
#   94,
#   100,
#   82,
#   94,
#   78,
#   84,
#   69,
#   93,
#   57,
#   76,
#   73,
#   83,
#   51,
#   94,
#   97,
#   93,
#   72,
#   77,
#   86,
#   100,
#   100,
#   100,
#   69,
#   100,
#   82,
#   71,
#   58,
#   59,
#   61,
#   93,
#   89,
#   60,
#   48,
#   100,
#   73,
#   89,
#   57,
#   72,
#   38,
#   93,
#   78,
#   70,
#   92,
#   97,
#   62,
#   72,
#   77,
#   58,
#   66,
#   100,
#   84,
#   45,
#   60,
#   84,
#   93,
#   98,
#   91,
#   67,
#   86,
#   97,
#   83,
#   89,
#   91,
#   36,
#   100,
#   72,
#   93,
#   98,
#   90,
#   86,
#   65,
#   74,
#   80,
#   86,
#   92,
#   87,
#   83,
#   69,
#   18,
#   81,
#   63,
#   59,
#   28,
#   32,
#   100,
#   69,
#   54,
#   100,
#   81,
#   80,
#   60,
#   94,
#   92,
#   88,
#   81,
#   47],
#  'Latitude': [-23.12,
#   -46.19,
#   62.45,
#   -34.53,
#   -21.21,
#   17.41,
#   -33.64,
#   78.22,
#   -34.42,
#   -33.59,
#   77.48,
#   -25.17,
#   -53.16,
#   57.91,
#   22.08,
#   50.23,
#   -29.69,
#   -38.31,
#   7.04,
#   -0.49,
#   20.2,
#   64.42,
#   18.42,
#   -9.8,
#   1.75,
#   58.52,
#   -45.87,
#   53.59,
#   42.65,
#   -9.67,
#   66.15,
#   27.91,
#   -54.81,
#   -41.87,
#   -30.17,
#   -32.59,
#   48.94,
#   41.42,
#   10.57,
#   53.96,
#   18.22,
#   55.74,
#   -33.21,
#   68.05,
#   38.42,
#   -10.07,
#   50.04,
#   -42.88,
#   -5.2,
#   -22.97,
#   41.91,
#   69.22,
#   32.87,
#   -33.69,
#   -30.97,
#   32.3,
#   -23.87,
#   -19.62,
#   65.61,
#   60.75,
#   25.27,
#   29.14,
#   50.28,
#   66.32,
#   58.81,
#   3.07,
#   65.58,
#   -19.76,
#   -46.13,
#   -0.74,
#   33.93,
#   14.2,
#   26.05,
#   38.18,
#   25.63,
#   -42.48,
#   39.31,
#   44.37,
#   28.68,
#   15.34,
#   53.05,
#   -0.6,
#   -43.3,
#   -42.78,
#   14.53,
#   54.78,
#   -33.93,
#   36.97,
#   36.69,
#   40.47,
#   59.7,
#   38.52,
#   47.57,
#   30.3,
#   71.98,
#   21.39,
#   50.24,
#   -23.58,
#   9.49,
#   5.44,
#   6.8,
#   39.24,
#   -13.73,
#   12.47,
#   26.14,
#   -46.43,
#   0.3,
#   50.2,
#   23,
#   62.57,
#   8.96,
#   -26.98,
#   72.79,
#   50.68,
#   -33.38,
#   22.57,
#   34.81,
#   45.62,
#   -20.41,
#   55.43,
#   -3.36,
#   69.38,
#   -13.71,
#   -46.28,
#   10.24,
#   35.54,
#   27.52,
#   -22.19,
#   47.36,
#   60.79,
#   43.41,
#   -3.71,
#   27.5,
#   12.18,
#   -25.41,
#   45.36,
#   5.28,
#   21.35,
#   51.4,
#   71.03,
#   52.12,
#   -0.39,
#   47.66,
#   5.35,
#   1.74,
#   67.67,
#   33.19,
#   15.44,
#   31.84,
#   49.72,
#   73.51,
#   14.69,
#   52.18,
#   11.15,
#   37.14,
#   -40.81,
#   13.22,
#   37.67,
#   25.29,
#   59.36,
#   66.08,
#   -2.57,
#   -34,
#   14.9,
#   53.34,
#   71.97,
#   14.97,
#   -29.95,
#   -28.65,
#   -43.53,
#   -36.31,
#   -6.32,
#   39,
#   -17.91,
#   66.4,
#   41.28,
#   38.25,
#   35.73,
#   47.38,
#   -0.61,
#   -19.8,
#   2.29,
#   56.29,
#   24.22,
#   66,
#   18,
#   29.03,
#   17.6,
#   51.92,
#   50.7,
#   -8.9,
#   22.89,
#   43.32,
#   7.98,
#   71.64,
#   35.3,
#   19.71,
#   34.64,
#   -39.03,
#   69.7,
#   57.02,
#   15.86,
#   34.35,
#   2.14,
#   36.84,
#   68.75,
#   69.44,
#   36.31,
#   55.34,
#   47.17,
#   -13.6,
#   41.47,
#   41.7,
#   8,
#   50.68,
#   -5.67,
#   16.26,
#   -8.93,
#   -12.89,
#   -8.42,
#   50.38,
#   29.7,
#   60.14,
#   27.87,
#   45.6,
#   -38.38,
#   51.88,
#   58.16,
#   -20.63,
#   -9.43,
#   52.64,
#   33.4,
#   60.91,
#   -2.64,
#   64.9,
#   43.56,
#   -29.52,
#   20.03,
#   39.95,
#   38.8,
#   65.28,
#   37.55,
#   13.58,
#   26.69,
#   5.38,
#   -20.34,
#   42.84,
#   6.88,
#   38.7,
#   43.74,
#   60.55,
#   24.34,
#   -6.22,
#   30.04,
#   67.8,
#   68.82],
#  'Longitude': [-134.97,
#   168.86,
#   -114.38,
#   20.04,
#   -159.78,
#   121.44,
#   115.35,
#   15.63,
#   19.24,
#   26.89,
#   -69.36,
#   45.06,
#   -70.91,
#   26.05,
#   -159.32,
#   -63.6,
#   152.93,
#   -60.23,
#   134.26,
#   15.91,
#   1.01,
#   -173.23,
#   -64.62,
#   -139.03,
#   40.07,
#   -117.13,
#   170.5,
#   142.95,
#   -73.75,
#   -35.74,
#   -65.72,
#   -15.45,
#   -68.31,
#   -73.83,
#   -50.22,
#   151.78,
#   -125.55,
#   -6.55,
#   72.64,
#   105.89,
#   42.5,
#   -97.86,
#   138.6,
#   39.51,
#   77.24,
#   -78.15,
#   46.89,
#   147.33,
#   -35.46,
#   -42.02,
#   -83.4,
#   -51.1,
#   -97.01,
#   -53.46,
#   22.13,
#   -64.78,
#   35.38,
#   34.74,
#   -37.64,
#   -137.51,
#   87.22,
#   21.3,
#   57.21,
#   -179.17,
#   -122.69,
#   172.79,
#   -170.99,
#   -44.31,
#   167.69,
#   -90.35,
#   134.5,
#   24.66,
#   -97.95,
#   -1.13,
#   74.93,
#   -73.76,
#   -74.98,
#   -100.35,
#   -17.76,
#   74.49,
#   158.65,
#   73.08,
#   -65.11,
#   147.06,
#   20.93,
#   -127.17,
#   18.42,
#   -122.03,
#   52.52,
#   141.48,
#   30.79,
#   -28.7,
#   -59.14,
#   -99.24,
#   102.47,
#   -157.74,
#   11.33,
#   149.07,
#   50.81,
#   73.37,
#   -58.16,
#   55.52,
#   15.06,
#   -85.66,
#   -81.79,
#   -67.52,
#   -78.23,
#   -66.38,
#   -102.17,
#   11.38,
#   38.73,
#   -56.83,
#   -56.15,
#   156.12,
#   148.01,
#   59.53,
#   -106.76,
#   -61.36,
#   57.7,
#   -116.48,
#   135.5,
#   178.42,
#   -76.2,
#   169.85,
#   -61.45,
#   -100.96,
#   -110.01,
#   -46.24,
#   36.65,
#   -161.76,
#   -124.22,
#   -38.6,
#   -81.44,
#   6.51,
#   -70.49,
#   -73.48,
#   115.24,
#   -158.09,
#   16.21,
#   27.85,
#   9.98,
#   -78.55,
#   -52.73,
#   48.53,
#   98.78,
#   12.69,
#   -82.53,
#   119.9,
#   -102.48,
#   -86.95,
#   80.55,
#   -16.54,
#   7.04,
#   123.77,
#   -8.45,
#   -62.99,
#   -59.52,
#   -122.08,
#   51.53,
#   143.24,
#   76.63,
#   150.8,
#   24.73,
#   -24.5,
#   15.05,
#   114.09,
#   -91.79,
#   -71.34,
#   153.62,
#   172.64,
#   -57.68,
#   155.48,
#   -77.4,
#   -64.53,
#   14.52,
#   -70.1,
#   -122.04,
#   140.83,
#   -61.86,
#   -47.36,
#   -174.35,
#   111.83,
#   62.58,
#   90.95,
#   57.56,
#   -102.23,
#   21.55,
#   -92.82,
#   108.05,
#   -127.42,
#   -35.15,
#   -109.91,
#   145.57,
#   49.82,
#   128.87,
#   37.18,
#   -155.08,
#   -120.46,
#   -67.58,
#   170.27,
#   82.07,
#   -97.07,
#   62.22,
#   27.99,
#   -2.46,
#   161.3,
#   -133.03,
#   139.8,
#   -131.65,
#   14.66,
#   24.21,
#   -87.06,
#   -93.05,
#   124.29,
#   -3.24,
#   132.75,
#   97.73,
#   125.41,
#   28.78,
#   20.74,
#   90.44,
#   -9.73,
#   -45.24,
#   -0.29,
#   -0.6,
#   142.48,
#   0.55,
#   59.7,
#   -46,
#   159.96,
#   -114.24,
#   49.69,
#   -46.05,
#   31.31,
#   45.76,
#   6.97,
#   28.61,
#   -75.83,
#   -94.76,
#   -9.45,
#   -126.83,
#   -121.99,
#   -8.03,
#   67.61,
#   -52.96,
#   57.76,
#   93.51,
#   73.1,
#   -9.42,
#   -81.71,
#   -151.26,
#   124.16,
#   -57.76,
#   -94.42,
#   130.41,
#   -51.19],
#  'Max_temp': [298.786,
#   287.59,
#   267.15,
#   291.15,
#   300.15,
#   294.886,
#   284.82,
#   265.15,
#   289.82,
#   289.26,
#   262.536,
#   298.136,
#   280.15,
#   279.82,
#   300.15,
#   272.15,
#   297.59,
#   291.186,
#   299.15,
#   296.686,
#   291.136,
#   264.936,
#   299.15,
#   301.536,
#   299.636,
#   273.15,
#   287.59,
#   269.986,
#   285.15,
#   298.15,
#   266.086,
#   290.15,
#   276.15,
#   286.15,
#   293.936,
#   300.37,
#   283.71,
#   276.986,
#   302.086,
#   262.286,
#   290.15,
#   273.15,
#   292.386,
#   270.436,
#   288.71,
#   294.236,
#   281.736,
#   290.93,
#   300.15,
#   300.036,
#   291.48,
#   277.15,
#   292.59,
#   290.686,
#   281.886,
#   293.15,
#   297.586,
#   297.15,
#   272.15,
#   275.836,
#   292.536,
#   290.636,
#   273.15,
#   262.686,
#   272.15,
#   299.386,
#   263.286,
#   296.15,
#   287.59,
#   301.15,
#   289.82,
#   288.286,
#   304.15,
#   286.15,
#   293.286,
#   286.15,
#   291.15,
#   291.48,
#   290.15,
#   291.686,
#   277.15,
#   302.086,
#   294.836,
#   290.93,
#   292.136,
#   283.15,
#   291.15,
#   294.26,
#   285.036,
#   282.15,
#   275.37,
#   288.286,
#   272.836,
#   299.82,
#   264.586,
#   301.48,
#   283.15,
#   299.286,
#   299.836,
#   302.286,
#   300.15,
#   286.436,
#   289.086,
#   304.15,
#   301.15,
#   289.786,
#   289.15,
#   274.15,
#   296.15,
#   272.15,
#   289.15,
#   292.686,
#   271.636,
#   273.586,
#   293.586,
#   300.536,
#   293.15,
#   277.04,
#   300.15,
#   278.536,
#   296.886,
#   259.186,
#   297.15,
#   288.15,
#   299.26,
#   299.15,
#   301.15,
#   292.686,
#   279.586,
#   277.15,
#   287.15,
#   300.37,
#   301.15,
#   301.136,
#   287.436,
#   280.15,
#   301.15,
#   301.48,
#   285.93,
#   271.186,
#   286.15,
#   289.15,
#   274.82,
#   299.536,
#   294.186,
#   276.286,
#   293.71,
#   299.386,
#   299.26,
#   277.15,
#   263.686,
#   300.15,
#   285.93,
#   300.786,
#   286.15,
#   290.036,
#   299.15,
#   293.15,
#   300.15,
#   277.336,
#   271.186,
#   301.386,
#   289.286,
#   295.036,
#   284.26,
#   266.686,
#   304.15,
#   287.15,
#   300.37,
#   285.93,
#   285.886,
#   302.236,
#   291.48,
#   282.936,
#   267.436,
#   285.37,
#   293.71,
#   290.37,
#   274.15,
#   299.586,
#   300.536,
#   297.15,
#   268.936,
#   295.15,
#   267.286,
#   300.286,
#   289.836,
#   305.15,
#   264.15,
#   280.15,
#   298.636,
#   299.26,
#   279.15,
#   297.436,
#   266.586,
#   286.186,
#   299.26,
#   294.26,
#   297.15,
#   262.036,
#   270.386,
#   302.15,
#   282.736,
#   293.686,
#   284.15,
#   264.286,
#   258.15,
#   291.48,
#   284.15,
#   280.37,
#   293.186,
#   292.15,
#   296.15,
#   299.82,
#   282.04,
#   301.986,
#   297.886,
#   298.086,
#   291.536,
#   292.486,
#   265.936,
#   285.236,
#   273.186,
#   291.15,
#   279.82,
#   289.26,
#   281.48,
#   269.786,
#   292.686,
#   301.286,
#   280.15,
#   278.086,
#   274.15,
#   288.886,
#   269.786,
#   281.15,
#   271.886,
#   301.15,
#   295.37,
#   286.48,
#   271.15,
#   294.26,
#   301.636,
#   300.536,
#   298.886,
#   300.15,
#   284.586,
#   301.786,
#   286.48,
#   282.59,
#   279.82,
#   296.15,
#   298.036,
#   297.59,
#   267.036,
#   276.15],
#  'Wind_speed': [5.72,
#   0.45,
#   6.7,
#   3.1,
#   6.2,
#   0.87,
#   4.57,
#   8.7,
#   3.13,
#   7.62,
#   4.92,
#   4.82,
#   17,
#   2.6,
#   7.2,
#   6.2,
#   1.5,
#   5.37,
#   2.6,
#   0.92,
#   3.37,
#   2.57,
#   5.7,
#   5.82,
#   4.02,
#   2.6,
#   8.49,
#   5.12,
#   3.6,
#   2.6,
#   2.12,
#   5.7,
#   2.1,
#   4.1,
#   3.47,
#   2.1,
#   7.7,
#   3.12,
#   3.92,
#   1.17,
#   5.1,
#   2.6,
#   3.42,
#   3.47,
#   6.82,
#   1.42,
#   0.62,
#   7.2,
#   2.1,
#   2.12,
#   3.1,
#   14.4,
#   3.6,
#   2.32,
#   2.97,
#   1.5,
#   3.32,
#   1.5,
#   17.5,
#   1.22,
#   3.77,
#   3.42,
#   2,
#   5.72,
#   1,
#   3.02,
#   4.02,
#   1,
#   0.45,
#   4.1,
#   2.1,
#   2.82,
#   6.7,
#   4.1,
#   3.12,
#   4.1,
#   1.87,
#   7.2,
#   4.6,
#   0.47,
#   1,
#   3.02,
#   4.32,
#   7.2,
#   1.07,
#   4.6,
#   5.1,
#   3.6,
#   2.02,
#   8.7,
#   2,
#   11.67,
#   4.32,
#   1.5,
#   4.62,
#   3.1,
#   1.79,
#   4.62,
#   1.22,
#   2.42,
#   5.1,
#   4.77,
#   1.37,
#   2.1,
#   3.1,
#   5.27,
#   5.1,
#   1,
#   9.8,
#   7.2,
#   2.6,
#   2.07,
#   6.12,
#   11.12,
#   2.02,
#   3.62,
#   2.6,
#   4.1,
#   5.1,
#   2.32,
#   0.57,
#   5.32,
#   4.1,
#   0.89,
#   4.6,
#   3.1,
#   5.7,
#   1.22,
#   4.77,
#   7.2,
#   7.7,
#   1.5,
#   6.2,
#   3.82,
#   0.42,
#   4.12,
#   2.1,
#   5.7,
#   0.5,
#   5.47,
#   1.5,
#   5.1,
#   6.2,
#   3.57,
#   0.62,
#   11.12,
#   1.52,
#   1.62,
#   5.7,
#   2.1,
#   1.52,
#   9.8,
#   1,
#   6.02,
#   3.1,
#   3.37,
#   9.8,
#   4.1,
#   2.1,
#   1.97,
#   8.92,
#   2.12,
#   4.92,
#   7.22,
#   3.6,
#   8.27,
#   3.1,
#   1.87,
#   4.1,
#   6.7,
#   2.92,
#   0.72,
#   3.1,
#   0.97,
#   0.82,
#   3.1,
#   5.7,
#   3.6,
#   3.1,
#   4.67,
#   4.57,
#   1.67,
#   1.42,
#   3.82,
#   4.67,
#   2.52,
#   3.57,
#   2.1,
#   1,
#   2.6,
#   2.87,
#   7.7,
#   5.7,
#   1.17,
#   1.97,
#   1.42,
#   5.7,
#   7.2,
#   2.1,
#   2.77,
#   3.77,
#   7.2,
#   1.22,
#   0.97,
#   2.6,
#   1.07,
#   6.2,
#   6.2,
#   7.2,
#   0.5,
#   3.57,
#   3.6,
#   6.2,
#   2.68,
#   5.7,
#   1.47,
#   1.87,
#   0.87,
#   2.77,
#   1.52,
#   0.97,
#   3.82,
#   7.72,
#   3.6,
#   1.5,
#   2.24,
#   3.1,
#   1.37,
#   1.42,
#   1.17,
#   4.6,
#   2.07,
#   3.6,
#   1.27,
#   1.67,
#   2.6,
#   0.87,
#   3.1,
#   4.1,
#   4.1,
#   6.2,
#   4.1,
#   6.12,
#   3.87,
#   5.67,
#   5.1,
#   0.77,
#   1.62,
#   4.1,
#   0.89,
#   10.3,
#   1,
#   0.77,
#   1.5,
#   1.87,
#   15.4]}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#                    City  Cloudiness  Humidity  Latitude  Longitude  Max_temp  \
# 0               Rikitea          24       100    -23.12    -134.97   298.786
# 1               Mataura           0        62    -46.19     168.86   287.590
# 2           Yellowknife          90        57     62.45    -114.38   267.150
# 3            Bredasdorp           0        82    -34.53      20.04   291.150
# 4                Avarua          48        65    -21.21    -159.78   300.150
# 5                 Tabuk          20        91     17.41     121.44   294.886
# 6             Busselton           8        66    -33.64     115.35   284.820
# 7          Longyearbyen          20        57     78.22      15.63   265.150
# 8              Hermanus          48        87    -34.42      19.24   289.820
# 9           Port Alfred           8        90    -33.59      26.89   289.260
# 10              Qaanaaq          80        87     77.48     -69.36   262.536
# 11               Beloha           0        64    -25.17      45.06   298.136
# 12         Punta Arenas          20        81    -53.16     -70.91   280.150
# 13                  Soe          12        69     57.91      26.05   279.820
# 14                Kapaa          75        61     22.08    -159.32   300.150
# 15   Havre-Saint-Pierre          40        86     50.23     -63.60   272.150
# 16              Grafton           0        77    -29.69     152.93   297.590
# 17               Barrow           0        45    -38.31     -60.23   291.186
# 18          Kloulklubed          90        88      7.04     134.26   299.150
# 19               Owando          44        93     -0.49      15.91   296.686
# 20             Tessalit           0        27     20.20       1.01   291.136
# 21          Provideniya          36       100     64.42    -173.23   264.936
# 22            Road Town           1        65     18.42     -64.62   299.150
# 23               Atuona          20        99     -9.80    -139.03   301.536
# 24                Wajir          48        53      1.75      40.07   299.636
# 25           High Level          90        71     58.52    -117.13   273.150
# 26              Dunedin           0        54    -45.87     170.50   287.590
# 27                 Okha          80       100     53.59     142.95   269.986
# 28               Albany          20        53     42.65     -73.75   285.150
# 29               Maceio           0        88     -9.67     -35.74   298.150
# ..                  ...         ...       ...       ...        ...       ...
# 226           Braintree          75        93     51.88       0.55   281.480
# 227       Baranchinskiy           0        98     58.16      59.70   269.786
# 228        Ponta do Sol          24        90    -20.63     -46.00   292.686
# 229             Honiara          80        86     -9.43     159.96   301.286
# 230              Rimbey          75        65     52.64    -114.24   280.150
# 231           Aligudarz          48        74     33.40      49.69   278.086
# 232              Narsaq          36        80     60.91     -46.05   274.150
# 233          Biharamulo           8        86     -2.64      31.31   288.886
# 234       Leshukonskoye          32        92     64.90      45.76   269.786
# 235        Saint-Joseph          90        87     43.56       6.97   281.150
# 236         Thaba-Tseka           8        83    -29.52      28.61   271.886
# 237    Santiago de Cuba          40        69     20.03     -75.83   301.150
# 238              Kodiak           1        18     39.95     -94.76   295.370
# 239             Colares          20        81     38.80      -9.45   286.480
# 240        Norman Wells          40        63     65.28    -126.83   271.150
# 241             Fremont          90        59     37.55    -121.99   294.260
# 242            Kolokani           0        28     13.58      -8.03   301.636
# 243                Johi           0        32     26.69      67.61   300.536
# 244           Sinnamary         100       100      5.38     -52.96   298.886
# 245     Bambous Virieux          75        69    -20.34      57.76   300.150
# 246                Hami          80        54     42.84      93.51   284.586
# 247           Dhidhdhoo           0       100      6.88      73.10   301.786
# 248             Cascais          20        81     38.70      -9.42   286.480
# 249            Goderich           0        80     43.74     -81.71   282.590
# 250               Kenai          20        60     60.55    -151.26   279.820
# 251            Ishigaki          40        94     24.34     124.16   296.150
# 252        Jacareacanga          32        92     -6.22     -57.76   298.036
# 253                Nome          90        88     30.04     -94.42   297.590
# 254       Batagay-Alyta          48        81     67.80     130.41   267.036
# 255       Qasigiannguit          68        47     68.82     -51.19   276.150
#
#      Wind_speed
# 0          5.72
# 1          0.45
# 2          6.70
# 3          3.10
# 4          6.20
# 5          0.87
# 6          4.57
# 7          8.70
# 8          3.13
# 9          7.62
# 10         4.92
# 11         4.82
# 12        17.00
# 13         2.60
# 14         7.20
# 15         6.20
# 16         1.50
# 17         5.37
# 18         2.60
# 19         0.92
# 20         3.37
# 21         2.57
# 22         5.70
# 23         5.82
# 24         4.02
# 25         2.60
# 26         8.49
# 27         5.12
# 28         3.60
# 29         2.60
# ..          ...
# 226        3.10
# 227        1.37
# 228        1.42
# 229        1.17
# 230        4.60
# 231        2.07
# 232        3.60
# 233        1.27
# 234        1.67
# 235        2.60
# 236        0.87
# 237        3.10
# 238        4.10
# 239        4.10
# 240        6.20
# 241        4.10
# 242        6.12
# 243        3.87
# 244        5.67
# 245        5.10
# 246        0.77
# 247        1.62
# 248        4.10
# 249        0.89
# 250       10.30
# 251        1.00
# 252        0.77
# 253        1.50
# 254        1.87
# 255       15.40
#
# [256 rows x 7 columns]

# %%
# Save dataframe to CSV
weather_df.to_csv("Weatherpy.csv")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Build Scatter plot for Latitude v Temperature

    
plt.scatter(weather_df["Latitude"], 
            weather_df["Max_temp"], c="grey",
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")
 
    

plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude") 
plt.title("City Latitude vs. Max Temperature")
plt.grid(True)

# Save the figure
plt.savefig("WeatherPy_Lat_v_Temp.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-bca4ffa32bb9> in <module>
#       9
#      10
# ---> 11 plt.ylabel("Max Temperature (F)")
#      12 plt.xlabel("Latitude")
#      13 plt.title("City Latitude vs. Max Temperature")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Build Scatter plot for Latitude v Humidity
plt.scatter(weather_df["Latitude"], 
            weather_df["Humidity"], c="grey",
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")

plt.title("City Latitude v Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("WeatherPy_Lat_v_Humidity.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-06fa27ddbd7d> in <module>
#       5             alpha=0.8, label="City")
#       6
# ----> 7 plt.title("City Latitude v Humidity")
#       8 plt.xlabel("Latitude")
#       9 plt.ylabel("Humidity (%)")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Build Scatter plot for Latitude v Cloudiness
plt.scatter(weather_df["Latitude"],
            weather_df["Cloudiness"], c="grey",
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="City")

plt.title="City Latitude v Cloudiness"
plt.xlabel= "Latitude"
plt.ylabel= "Cloudiness (%)"
plt.grid=(True)


# Save the figure
plt.savefig("WeatherPy_Lat_v_Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Build Scatter plot for Latitude v Wind Speed
plt.scatter(weather_df["Latitude"],
           weather_df["Wind_speed"], c="grey",
           edgecolor="black",linewidth=1, marker="o",
           alpha=0.8, label="City")

plt.title = "City Latitude vs Wind Speed"
plt.xlabel= "Latitude"
plt.ylabel= "Wind Speed(%)"
plt.grid=(True)

plt.savefig("WeatherPy_Lat_v_Wind.png")

plt.show()
